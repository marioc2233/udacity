# %%
import pandas as pd
import psycopg2

# %%
conn = psycopg2.connect(host="postgres_udacity", dbname="udacity", user="udacity", password="udacity")

# %%
df_songs = pd.read_sql("SELECT * FROM sparkifydb.songs;", conn)

# %%
df_songs
# Out:
#                song_id                                              title  \
# 0   SORAMLE12AB017C8B0                                     Auguri Cha Cha
# 1   SOPSWQW12A6D4F8781                              Made Like This (Live)
# 2   SOKEJEJ12A8C13E0D0                           The Urgency (LP Version)
# 3   SONYPOM12A8C13B2D7  I Think My Wife Is Running Around On Me (Taco ...
# 4   SOMUYGI12AB0188633                                           La Culpa
# ..                 ...                                                ...
# 66  SOMJBYD12A6D4F8557                              Keepin It Real (Skit)
# 67  SOIAZJW12AB01853F1                                         Pink World
# 68  SODAUVL12A8C13D184                                          Prognosis
# 69  SOVYKGO12AB0187199                               Crazy Mixed Up World
# 70  SOZVMJI12AB01808AF                                    Synthetic Dream
#
#              artist_id  year   duration
# 0   ARHHO3O1187B989413     0  191.84281
# 1   ARGIWFO1187B9B55B7     0  225.09669
# 2   ARC43071187B990240     0  245.21098
# 3   ARDNS031187B9924F0  2005  186.48771
# 4   ARL7K851187B99ACD2     0  226.35057
# ..                 ...   ...        ...
# 66  ARD0S291187B9B7BF5     0  114.78159
# 67  AR8ZCNI1187B9A069B  1984  269.81832
# 68  ARWB3G61187FB49404  2000  363.85914
# 69  ARH4Z031187B9A71F2  1961  156.39465
# 70  ARNPAGP1241B9C7FD4     0  165.69424
#
# [71 rows x 5 columns]

# %%
df_artists = pd.read_sql("SELECT * FROM sparkifydb.artists where artist_id = 'ARL7K851187B99ACD2';", conn)

# %%
df_artists
# Out:
#             artist_id artist_name artist_location artist_latitude  \
# 0  ARL7K851187B99ACD2   Andy Andy                             NaN
#
#   artist_longitude
# 0              NaN

# %%
df_users = pd.read_sql('SELECT * FROM sparkifydb.users', conn)

# %%
df_users
# Out:
#    user_id first_name last_name gender level
# 0       32       Lily     Burns      F  free
# 1       91     Jayden      Bell      M  free
# 2        8     Kaylee   Summers      F  free
# 3       76     Jayden     Duffy      F  free
# 4                None      None   None  paid
# ..     ...        ...       ...    ...   ...
# 93      18      Jacob    Rogers      M  free
# 94      99        Ann     Banks      F  free
# 95      15       Lily      Koch      F  paid
# 96      74     Braden    Parker      M  free
# 97      16      Rylan    George      M  paid
#
# [98 rows x 5 columns]

# %%
df_time = pd.read_sql('SELECT * FROM sparkifydb.time', conn)

# %%
df_time
# Out:
#                    start_time  hour  day  week  month  year   weakday
# 0     2018-11-04 00:50:03.796     0    4    44     11  2018    Sunday
# 1     2018-11-04 02:54:52.796     2    4    44     11  2018    Sunday
# 2     2018-11-04 02:58:57.796     2    4    44     11  2018    Sunday
# 3     2018-11-04 03:02:20.796     3    4    44     11  2018    Sunday
# 4     2018-11-04 04:35:52.796     4    4    44     11  2018    Sunday
# ...                       ...   ...  ...   ...    ...   ...       ...
# 6815  2018-11-15 23:39:05.796    23   15    46     11  2018  Thursday
# 6816  2018-11-15 23:42:18.796    23   15    46     11  2018  Thursday
# 6817  2018-11-15 23:46:20.796    23   15    46     11  2018  Thursday
# 6818  2018-11-15 23:52:16.796    23   15    46     11  2018  Thursday
# 6819  2018-11-15 23:57:05.796    23   15    46     11  2018  Thursday
#
# [6820 rows x 7 columns]
