# %%
import pandas as pd
import psycopg2

# %%
conn = psycopg2.connect(host="postgres_udacity", dbname="udacity", user="udacity", password="udacity")

# %%
df = pd.read_json('../data/log_data/2018-11-01-events.json', lines=True)

# %%
df
# Out:
#                         artist       auth firstName gender  itemInSession  \
# 0                         None  Logged In    Walter      M              0
# 1                         None  Logged In    Kaylee      F              0
# 2                      Des'ree  Logged In    Kaylee      F              1
# 3                         None  Logged In    Kaylee      F              2
# 4                      Mr Oizo  Logged In    Kaylee      F              3
# 5                   Tamba Trio  Logged In    Kaylee      F              4
# 6               The Mars Volta  Logged In    Kaylee      F              5
# 7            Infected Mushroom  Logged In    Kaylee      F              6
# 8   Blue October / Imogen Heap  Logged In    Kaylee      F              7
# 9                    Girl Talk  Logged In    Kaylee      F              8
# 10             Black Eyed Peas  Logged In    Sylvie      F              0
# 11                        None  Logged In      Ryan      M              0
# 12                Fall Out Boy  Logged In      Ryan      M              1
# 13                      M.I.A.  Logged In      Ryan      M              2
# 14                    Survivor  Logged In    Jayden      M              0
#
#    lastName     length level                                      location  \
# 0      Frye        NaN  free             San Francisco-Oakland-Hayward, CA
# 1   Summers        NaN  free                   Phoenix-Mesa-Scottsdale, AZ
# 2   Summers  246.30812  free                   Phoenix-Mesa-Scottsdale, AZ
# 3   Summers        NaN  free                   Phoenix-Mesa-Scottsdale, AZ
# 4   Summers  144.03873  free                   Phoenix-Mesa-Scottsdale, AZ
# 5   Summers  177.18812  free                   Phoenix-Mesa-Scottsdale, AZ
# 6   Summers  380.42077  free                   Phoenix-Mesa-Scottsdale, AZ
# 7   Summers  440.26730  free                   Phoenix-Mesa-Scottsdale, AZ
# 8   Summers  241.39710  free                   Phoenix-Mesa-Scottsdale, AZ
# 9   Summers  160.15628  free                   Phoenix-Mesa-Scottsdale, AZ
# 10     Cruz  214.93506  free  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 11    Smith        NaN  free            San Jose-Sunnyvale-Santa Clara, CA
# 12    Smith  200.72444  free            San Jose-Sunnyvale-Santa Clara, CA
# 13    Smith  233.71710  free            San Jose-Sunnyvale-Santa Clara, CA
# 14      Fox  245.36771  free                      New Orleans-Metairie, LA
#
#    method      page   registration  sessionId  \
# 0     GET      Home  1540919166796         38
# 1     GET      Home  1540344794796        139
# 2     PUT  NextSong  1540344794796        139
# 3     GET   Upgrade  1540344794796        139
# 4     PUT  NextSong  1540344794796        139
# 5     PUT  NextSong  1540344794796        139
# 6     PUT  NextSong  1540344794796        139
# 7     PUT  NextSong  1540344794796        139
# 8     PUT  NextSong  1540344794796        139
# 9     PUT  NextSong  1540344794796        139
# 10    PUT  NextSong  1540266185796          9
# 11    GET      Home  1541016707796        169
# 12    PUT  NextSong  1541016707796        169
# 13    PUT  NextSong  1541016707796        169
# 14    PUT  NextSong  1541033612796        100
#
#                                                 song  status             ts  \
# 0                                               None     200  1541105830796
# 1                                               None     200  1541106106796
# 2                                       You Gotta Be     200  1541106106796
# 3                                               None     200  1541106132796
# 4                                            Flat 55     200  1541106352796
# 5                       Quem Quiser Encontrar O Amor     200  1541106496796
# 6                                          Eriatarka     200  1541106673796
# 7                                    Becoming Insane     200  1541107053796
# 8                                    Congratulations     200  1541107493796
# 9                                         Once again     200  1541107734796
# 10                                           Pump It     200  1541108520796
# 11                                              None     200  1541109015796
# 12                    Nobody Puts Baby In The Corner     200  1541109125796
# 13  Mango Pickle Down River (With The Wilcannia Mob)     200  1541109325796
# 14                                  Eye Of The Tiger     200  1541110994796
#
#                                             userAgent  userId
# 0   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      39
# 1   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 2   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 3   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 4   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 5   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 7   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 8   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 9   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 10  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      10
# 11  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 12  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 13  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 14  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     101

# %%
df_used = df[df['page'] == 'NextSong']

# %%
df_used
# Out:
#                         artist       auth firstName gender  itemInSession  \
# 2                      Des'ree  Logged In    Kaylee      F              1
# 4                      Mr Oizo  Logged In    Kaylee      F              3
# 5                   Tamba Trio  Logged In    Kaylee      F              4
# 6               The Mars Volta  Logged In    Kaylee      F              5
# 7            Infected Mushroom  Logged In    Kaylee      F              6
# 8   Blue October / Imogen Heap  Logged In    Kaylee      F              7
# 9                    Girl Talk  Logged In    Kaylee      F              8
# 10             Black Eyed Peas  Logged In    Sylvie      F              0
# 12                Fall Out Boy  Logged In      Ryan      M              1
# 13                      M.I.A.  Logged In      Ryan      M              2
# 14                    Survivor  Logged In    Jayden      M              0
#
#    lastName     length level                                      location  \
# 2   Summers  246.30812  free                   Phoenix-Mesa-Scottsdale, AZ
# 4   Summers  144.03873  free                   Phoenix-Mesa-Scottsdale, AZ
# 5   Summers  177.18812  free                   Phoenix-Mesa-Scottsdale, AZ
# 6   Summers  380.42077  free                   Phoenix-Mesa-Scottsdale, AZ
# 7   Summers  440.26730  free                   Phoenix-Mesa-Scottsdale, AZ
# 8   Summers  241.39710  free                   Phoenix-Mesa-Scottsdale, AZ
# 9   Summers  160.15628  free                   Phoenix-Mesa-Scottsdale, AZ
# 10     Cruz  214.93506  free  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 12    Smith  200.72444  free            San Jose-Sunnyvale-Santa Clara, CA
# 13    Smith  233.71710  free            San Jose-Sunnyvale-Santa Clara, CA
# 14      Fox  245.36771  free                      New Orleans-Metairie, LA
#
#    method      page   registration  sessionId  \
# 2     PUT  NextSong  1540344794796        139
# 4     PUT  NextSong  1540344794796        139
# 5     PUT  NextSong  1540344794796        139
# 6     PUT  NextSong  1540344794796        139
# 7     PUT  NextSong  1540344794796        139
# 8     PUT  NextSong  1540344794796        139
# 9     PUT  NextSong  1540344794796        139
# 10    PUT  NextSong  1540266185796          9
# 12    PUT  NextSong  1541016707796        169
# 13    PUT  NextSong  1541016707796        169
# 14    PUT  NextSong  1541033612796        100
#
#                                                 song  status             ts  \
# 2                                       You Gotta Be     200  1541106106796
# 4                                            Flat 55     200  1541106352796
# 5                       Quem Quiser Encontrar O Amor     200  1541106496796
# 6                                          Eriatarka     200  1541106673796
# 7                                    Becoming Insane     200  1541107053796
# 8                                    Congratulations     200  1541107493796
# 9                                         Once again     200  1541107734796
# 10                                           Pump It     200  1541108520796
# 12                    Nobody Puts Baby In The Corner     200  1541109125796
# 13  Mango Pickle Down River (With The Wilcannia Mob)     200  1541109325796
# 14                                  Eye Of The Tiger     200  1541110994796
#
#                                             userAgent  userId
# 2   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 4   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 5   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 7   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 8   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 9   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 10  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      10
# 12  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 13  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 14  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     101

# %%
columns = ['start_time', 'user_id', 'level', 'song_id', 'artist_id', 'session_id', 'location', 'user_agent']

# %%
df_used = df_used[['ts', 'userId', 'level', 'song', 'artist', 'sessionId', 'location', 'userAgent']]

# %%
df_used
# Out:
#                ts  userId level  \
# 2   1541106106796       8  free
# 4   1541106352796       8  free
# 5   1541106496796       8  free
# 6   1541106673796       8  free
# 7   1541107053796       8  free
# 8   1541107493796       8  free
# 9   1541107734796       8  free
# 10  1541108520796      10  free
# 12  1541109125796      26  free
# 13  1541109325796      26  free
# 14  1541110994796     101  free
#
#                                                 song  \
# 2                                       You Gotta Be
# 4                                            Flat 55
# 5                       Quem Quiser Encontrar O Amor
# 6                                          Eriatarka
# 7                                    Becoming Insane
# 8                                    Congratulations
# 9                                         Once again
# 10                                           Pump It
# 12                    Nobody Puts Baby In The Corner
# 13  Mango Pickle Down River (With The Wilcannia Mob)
# 14                                  Eye Of The Tiger
#
#                         artist  sessionId  \
# 2                      Des'ree        139
# 4                      Mr Oizo        139
# 5                   Tamba Trio        139
# 6               The Mars Volta        139
# 7            Infected Mushroom        139
# 8   Blue October / Imogen Heap        139
# 9                    Girl Talk        139
# 10             Black Eyed Peas          9
# 12                Fall Out Boy        169
# 13                      M.I.A.        169
# 14                    Survivor        100
#
#                                         location  \
# 2                    Phoenix-Mesa-Scottsdale, AZ
# 4                    Phoenix-Mesa-Scottsdale, AZ
# 5                    Phoenix-Mesa-Scottsdale, AZ
# 6                    Phoenix-Mesa-Scottsdale, AZ
# 7                    Phoenix-Mesa-Scottsdale, AZ
# 8                    Phoenix-Mesa-Scottsdale, AZ
# 9                    Phoenix-Mesa-Scottsdale, AZ
# 10  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 12            San Jose-Sunnyvale-Santa Clara, CA
# 13            San Jose-Sunnyvale-Santa Clara, CA
# 14                      New Orleans-Metairie, LA
#
#                                             userAgent
# 2   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 5   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 6   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 7   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 8   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 9   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 10  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 12  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 13  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 14  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...

# %%
def return_song_id(song, conn):
    sql = f"select song_id, artist_id from sparkifydb.songs where title = '{song}';"
    print(sql)
    df = pd.read_sql(sql, conn)
    return df

# %%
for i, line in df_used.iterrows():
    print(line.song)
    df = return_song_id(line.song, conn)
    print(df)
# Out:
# You Gotta Be
# select song_id, artist_id from sparkifydb.songs where title = 'You Gotta Be';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Flat 55
# select song_id, artist_id from sparkifydb.songs where title = 'Flat 55';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Quem Quiser Encontrar O Amor
# select song_id, artist_id from sparkifydb.songs where title = 'Quem Quiser Encontrar O Amor';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Eriatarka
# select song_id, artist_id from sparkifydb.songs where title = 'Eriatarka';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Becoming Insane
# select song_id, artist_id from sparkifydb.songs where title = 'Becoming Insane';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Congratulations
# select song_id, artist_id from sparkifydb.songs where title = 'Congratulations';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Once again
# select song_id, artist_id from sparkifydb.songs where title = 'Once again';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Pump It
# select song_id, artist_id from sparkifydb.songs where title = 'Pump It';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Nobody Puts Baby In The Corner
# select song_id, artist_id from sparkifydb.songs where title = 'Nobody Puts Baby In The Corner';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Mango Pickle Down River (With The Wilcannia Mob)
# select song_id, artist_id from sparkifydb.songs where title = 'Mango Pickle Down River (With The Wilcannia Mob)';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
# Eye Of The Tiger
# select song_id, artist_id from sparkifydb.songs where title = 'Eye Of The Tiger';
# Empty DataFrame
# Columns: [song_id, artist_id]
# Index: []
